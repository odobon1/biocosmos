# %%
from utils.utils import load_pickle, paths, load_json
from collections import Counter
from dataclasses import dataclass, fields

# %%
DATASET = "nymph"  # {bryo, cub, lepid, nymph}

# %%
split = load_pickle(paths["metadata"][DATASET] / "splits/D10/split.pkl")
print([f.name for f in fields(split)])

# %% [markdown]
# #### data_indexes

# %%
split.data_indexes["val"]

# %% [markdown]
# #### enc2cid (Class Encoding to Class ID Mapping)

# %%
split.enc2cid

# %% [markdown]
# #### nshot

# %%
split.nshot

# %% [markdown]
# #### class_counts

# %%
split.class_counts["trainval"][:50]

# %% [markdown]
# #### norm_mean, norm_std

# %%
split.norm_mean

# %%
split.norm_std
